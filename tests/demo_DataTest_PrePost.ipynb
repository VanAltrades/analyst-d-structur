# %%
import sys
sys.path.append('../')

from src.DataTest import DataTest

# %%
test = DataTest(

sql_path="../src/sql/data_test_time_series.sql", # this is relative to the location you run this instance from
project="e-commerce-demo-v",
dataset="summary",
table="s_ga_organic",
date_start="2017-01-01",
date_end="2017-03-28",
dim_sql_date="date",
dim_sql_index="entry_page",
dim_sql_dimensions=None,
kpis=["visits", "transactions", "revenue"],
aggs=["SUM","SUM","SUM"],
where_clause="",

dim_test_index="url",
regex=".",
date_test="2017-02-05",
batch_table="e-commerce-demo-v.tests.Batch1_product_content_2017-02-05"
)
vars(test)
# Out:
# {'_credential_path': '..\\secret.json',
#  '_client': <google.cloud.bigquery.client.Client at 0x2609ceb1410>,
#  '_sql_path': '../src/sql/data_test_time_series.sql',
#  '_project': 'e-commerce-demo-v',
#  '_dataset': 'summary',
#  '_table': 's_ga_organic',
#  '_sql_file_string': 'SELECT\n*\n    -- {_dim_sql_date}\n    -- -- DISTINCT {_dim_index}\n    -- {_dim_sql_index}\n    -- {_dim_sql_dimensions}\n    -- {_kpi_aggregates}\nFROM `{_project}.{_dataset}.{_table}` facts\n  INNER JOIN `{_batch_tbl}` batch\n    on REGEXP_EXTRACT(facts.{_dim_sql_index},r"{_regex}") = REGEXP_EXTRACT(batch.{_dim_test_index},r"{_regex}")    \nWHERE \n    date BETWEEN "{_date_start}" AND "{_date_end}"\n    {_where_clause}\n    -- {_group_by_clause}',
#  '_sql_variables': {'_batch_tbl',
#   '_dataset',
#   '_date_end',
#   '_date_start',
#   '_dim_index',
#   '_dim_sql_date',
#   '_dim_sql_dimensions',
#   '_dim_sql_index',
#   '_dim_test_index',
#   '_group_by_clause',
#   '_kpi_aggregates',
#   '_project',
#   '_regex',
#   '_table',
#   '_where_clause'},
#  '_date_start': '2017-01-01',
#  '_date_end': '2017-03-28',
#  '_dim_sql_date': 'date',
#  '_dim_sql_index': 'entry_page',
#  '_dim_sql_dimensions': None,
#  '_dim_dict': {'_dim_sql_date': 'date',
#   '_dim_sql_index': 'entry_page',
#   '_dim_sql_dimensions': None},
#  '_dim_key_list': ['_dim_sql_date', '_dim_sql_index', '_dim_sql_dimensions'],
#  '_dim_value_list': ['date', 'entry_page'],
#  '_kpis': ['visits', 'transactions', 'revenue'],
#  '_aggs': ['SUM', 'SUM', 'SUM'],
#  '_kpi_aggregates': 'SUM(visits) visits, SUM(transactions) transactions, SUM(revenue) revenue, ',
#  '_where_clause': '',
#  '_group_by_clause': 'GROUP BY 1,2',
#  '_sql_file_string_formatted': 'SELECT\n*\n    -- date,\n    -- -- DISTINCT _dim_index\n    -- entry_page,\n    -- \n    -- SUM(visits) visits, SUM(transactions) transactions, SUM(revenue) revenue, \nFROM `e-commerce-demo-v.summary.s_ga_organic` facts\n  INNER JOIN `e-commerce-demo-v.tests.Batch1_product_content_2017-02-05` batch\n    on REGEXP_EXTRACT(facts.entry_page,r".") = REGEXP_EXTRACT(batch.url,r".")    \nWHERE \n    date BETWEEN "2017-01-01" AND "2017-03-28"\n    \n    -- GROUP BY 1,2',
#  '_dim_test_index': 'url',
#  '_regex': '.',
#  '_date_test': '2017-02-05',
#  '_date_test_prior': '2017-02-04',
#  '_batch_tbl': 'e-commerce-demo-v.tests.Batch1_product_content_2017-02-05',
#  '_pre_period': ['2017-01-01', '2017-02-04'],
#  '_post_period': ['2017-02-05', '2017-03-28'],
#  '_days_in_pre': datetime.timedelta(days=34),
#  '_days_in_post': datetime.timedelta(days=51)}

# %%
test.get_data_sql()
test._data_sql
# Out:
#              date                                         entry_page   medium  \
# 0      2017-03-09         shop.googlemerchandisestore.com/store.html  organic
# 1      2017-03-09         shop.googlemerchandisestore.com/store.html  organic
# 2      2017-03-09         shop.googlemerchandisestore.com/store.html  organic
# 3      2017-03-09         shop.googlemerchandisestore.com/store.html  organic
# 4      2017-03-09         shop.googlemerchandisestore.com/store.html  organic
# ...           ...                                                ...      ...
# 89728  2017-03-01  shop.googlemerchandisestore.com/google+redesig...  organic
# 89729  2017-03-01  shop.googlemerchandisestore.com/google+redesig...  organic
# 89730  2017-03-01  shop.googlemerchandisestore.com/google+redesig...  organic
# 89731  2017-03-01  shop.googlemerchandisestore.com/google+redesig...  organic
# 89732  2017-03-01  shop.googlemerchandisestore.com/google+redesig...  organic
#
#        isTrueDirect  visits  transactions  revenue  pageviews  bounce_rate  \
# 0              True       5             0      NaN          8          0.8
# 1              True       5             0      NaN          8          0.8
# 2              True       5             0      NaN          8          0.8
# 3              True       5             0      NaN          8          0.8
# 4              True       5             0      NaN          8          0.8
# ...             ...     ...           ...      ...        ...          ...
# 89728          True       1             0      NaN          3          0.0
# 89729          True       1             0      NaN          3          0.0
# 89730          True       1             0      NaN          3          0.0
# 89731          True       1             0      NaN          3          0.0
# 89732          True       1             0      NaN          3          0.0
#
#                                           entry_page_dim  ... bizdays_month  \
# 0             shop.googlemerchandisestore.com/store.html  ...            21
# 1             shop.googlemerchandisestore.com/store.html  ...            21
# 2             shop.googlemerchandisestore.com/store.html  ...            21
# 3             shop.googlemerchandisestore.com/store.html  ...            21
# 4             shop.googlemerchandisestore.com/store.html  ...            21
# ...                                                  ...  ...           ...
# 89728  shop.googlemerchandisestore.com/google+redesig...  ...            21
# 89729  shop.googlemerchandisestore.com/google+redesig...  ...            21
# 89730  shop.googlemerchandisestore.com/google+redesig...  ...            21
# 89731  shop.googlemerchandisestore.com/google+redesig...  ...            21
# 89732  shop.googlemerchandisestore.com/google+redesig...  ...            21
#
#       date_quarter bizdays_quarter   date_year bizdays_year  \
# 0       2017-01-01              63  2017-01-01          254
# 1       2017-01-01              63  2017-01-01          254
# 2       2017-01-01              63  2017-01-01          254
# 3       2017-01-01              63  2017-01-01          254
# 4       2017-01-01              63  2017-01-01          254
# ...            ...             ...         ...          ...
# 89728   2017-01-01              63  2017-01-01          254
# 89729   2017-01-01              63  2017-01-01          254
# 89730   2017-01-01              63  2017-01-01          254
# 89731   2017-01-01              63  2017-01-01          254
# 89732   2017-01-01              63  2017-01-01          254
#
#                                                      url    id  test_batch  \
# 0      shop.googlemerchandisestore.com/google+redesig...  <NA>           1
# 1      shop.googlemerchandisestore.com/google+redesig...  <NA>           1
# 2      shop.googlemerchandisestore.com/google+redesig...  <NA>           1
# 3      shop.googlemerchandisestore.com/google+redesig...  <NA>           1
# 4      shop.googlemerchandisestore.com/google+redesig...  <NA>           1
# ...                                                  ...   ...         ...
# 89728  shop.googlemerchandisestore.com/google+redesig...  <NA>           1
# 89729  shop.googlemerchandisestore.com/google+redesig...  <NA>           1
# 89730  shop.googlemerchandisestore.com/google+redesig...  <NA>           1
# 89731  shop.googlemerchandisestore.com/google+redesig...  <NA>           1
# 89732  shop.googlemerchandisestore.com/google+redesig...  <NA>           1
#
#        test_group   test_date
# 0            Test  2017-02-05
# 1            Test  2017-02-05
# 2            Test  2017-02-05
# 3            Test  2017-02-05
# 4            Test  2017-02-05
# ...           ...         ...
# 89728        Test  2017-02-05
# 89729        Test  2017-02-05
# 89730        Test  2017-02-05
# 89731        Test  2017-02-05
# 89732        Test  2017-02-05
#
# [89733 rows x 38 columns]

# %%
test._sql_file_string_formatted
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 test._sql_file_string_formatted
#
# NameError: name 'test' is not defined

# %% [markdown]
# # Compare Pre vs. Post

# %%
test.get_data_pre_post()
display(test._data_pre.head())
display(test._data_post.head())
# Out:
#           date                            entry_page   medium  isTrueDirect  \
# 294 2017-02-02  shop.googlemerchandisestore.com/home  organic          <NA>
# 295 2017-02-02  shop.googlemerchandisestore.com/home  organic          <NA>
# 296 2017-02-02  shop.googlemerchandisestore.com/home  organic          <NA>
# 297 2017-02-02  shop.googlemerchandisestore.com/home  organic          <NA>
# 298 2017-02-02  shop.googlemerchandisestore.com/home  organic          <NA>
#
#      visits  transactions  revenue  pageviews  bounce_rate  \
# 294       2             0      NaN          3          0.5
# 295       2             0      NaN          3          0.5
# 296       2             0      NaN          3          0.5
# 297       2             0      NaN          3          0.5
# 298       2             0      NaN          3          0.5
#
#                            entry_page_dim  ... bizdays_month date_quarter  \
# 294  shop.googlemerchandisestore.com/home  ...            20   2017-01-01
# 295  shop.googlemerchandisestore.com/home  ...            20   2017-01-01
# 296  shop.googlemerchandisestore.com/home  ...            20   2017-01-01
# 297  shop.googlemerchandisestore.com/home  ...            20   2017-01-01
# 298  shop.googlemerchandisestore.com/home  ...            20   2017-01-01
#
#     bizdays_quarter   date_year bizdays_year  \
# 294              63  2017-01-01          254
# 295              63  2017-01-01          254
# 296              63  2017-01-01          254
# 297              63  2017-01-01          254
# 298              63  2017-01-01          254
#
#                                                    url    id  test_batch  \
# 294  shop.googlemerchandisestore.com/google+redesig...  <NA>           1
# 295  shop.googlemerchandisestore.com/google+redesig...  <NA>           1
# 296  shop.googlemerchandisestore.com/google+redesig...  <NA>           1
# 297  shop.googlemerchandisestore.com/google+redesig...  <NA>           1
# 298  shop.googlemerchandisestore.com/google+redesig...  <NA>           1
#
#      test_group   test_date
# 294        Test  2017-02-05
# 295        Test  2017-02-05
# 296        Test  2017-02-05
# 297        Test  2017-02-05
# 298        Test  2017-02-05
#
# [5 rows x 38 columns]
#         date                                         entry_page   medium  \
# 0 2017-02-19  shop.googlemerchandisestore.com/google+redesig...  organic
# 1 2017-02-19  shop.googlemerchandisestore.com/google+redesig...  organic
# 2 2017-02-19  shop.googlemerchandisestore.com/google+redesig...  organic
# 3 2017-02-19  shop.googlemerchandisestore.com/google+redesig...  organic
# 4 2017-02-19  shop.googlemerchandisestore.com/google+redesig...  organic
#
#    isTrueDirect  visits  transactions  revenue  pageviews  bounce_rate  \
# 0          <NA>       1             0      NaN          1          1.0
# 1          <NA>       1             0      NaN          1          1.0
# 2          <NA>       1             0      NaN          1          1.0
# 3          <NA>       1             0      NaN          1          1.0
# 4          <NA>       1             0      NaN          1          1.0
#
#                                       entry_page_dim  ... bizdays_month  \
# 0  shop.googlemerchandisestore.com/google+redesig...  ...            20
# 1  shop.googlemerchandisestore.com/google+redesig...  ...            20
# 2  shop.googlemerchandisestore.com/google+redesig...  ...            20
# 3  shop.googlemerchandisestore.com/google+redesig...  ...            20
# 4  shop.googlemerchandisestore.com/google+redesig...  ...            20
#
#   date_quarter bizdays_quarter   date_year bizdays_year  \
# 0   2017-01-01              63  2017-01-01          254
# 1   2017-01-01              63  2017-01-01          254
# 2   2017-01-01              63  2017-01-01          254
# 3   2017-01-01              63  2017-01-01          254
# 4   2017-01-01              63  2017-01-01          254
#
#                                                  url    id  test_batch  \
# 0  shop.googlemerchandisestore.com/google+redesig...  <NA>           1
# 1  shop.googlemerchandisestore.com/google+redesig...  <NA>           1
# 2  shop.googlemerchandisestore.com/google+redesig...  <NA>           1
# 3  shop.googlemerchandisestore.com/google+redesig...  <NA>           1
# 4  shop.googlemerchandisestore.com/google+redesig...  <NA>           1
#
#    test_group   test_date
# 0        Test  2017-02-05
# 1        Test  2017-02-05
# 2        Test  2017-02-05
# 3        Test  2017-02-05
# 4        Test  2017-02-05
#
# [5 rows x 38 columns]

# %%
# show record percent changes pre vs. post
page_change = test.get_data_pre_post_comparison(dimension_column="entry_page",metric_column="visits",metric_column_agg="sum")
page_change
# Out:
#                                                     visits_pre  visits_post  \
# entry_page
# shop.googlemerchandisestore.com/asearch.html               210         2730
# shop.googlemerchandisestore.com/asearch.html/qu...          21          168
# shop.googlemerchandisestore.com/basket.html                441         7119
# shop.googlemerchandisestore.com/google+redesign...          84         3339
# shop.googlemerchandisestore.com/google+redesign...          21          735
# ...                                                        ...          ...
# shop.googlemerchandisestore.com/signin.html                483         6636
# shop.googlemerchandisestore.com/store-policies/...          21          504
# shop.googlemerchandisestore.com/store-policies/...          21          231
# shop.googlemerchandisestore.com/store.html                 189         3255
# shop.googlemerchandisestore.com/storeitem.html              42          231
#
#                                                     delta    %delta
# entry_page
# shop.googlemerchandisestore.com/asearch.html         2520  1200.00%
# shop.googlemerchandisestore.com/asearch.html/qu...    147   700.00%
# shop.googlemerchandisestore.com/basket.html          6678  1514.29%
# shop.googlemerchandisestore.com/google+redesign...   3255  3875.00%
# shop.googlemerchandisestore.com/google+redesign...    714  3400.00%
# ...                                                   ...       ...
# shop.googlemerchandisestore.com/signin.html          6153  1273.91%
# shop.googlemerchandisestore.com/store-policies/...    483  2300.00%
# shop.googlemerchandisestore.com/store-policies/...    210  1000.00%
# shop.googlemerchandisestore.com/store.html           3066  1622.22%
# shop.googlemerchandisestore.com/storeitem.html        189   450.00%
#
# [98 rows x 4 columns]

# %%
improving = get_improving_dimensions(page_change)
improving
